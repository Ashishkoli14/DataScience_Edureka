# %%
# !pip install fuzzy-c-means
# Out:
# Requirement already satisfied: fuzzy-c-means in c:\users\admin\anaconda3\lib\site-packages (1.7.0)
# Requirement already satisfied: pydantic<2.0.0,>=1.9.0 in c:\users\admin\anaconda3\lib\site-packages (from fuzzy-c-means) (1.10.12)
# Requirement already satisfied: numpy<2.0.0,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from fuzzy-c-means) (1.23.5)
# Requirement already satisfied: typer<0.5.0,>=0.4.0 in c:\users\admin\anaconda3\lib\site-packages (from fuzzy-c-means) (0.4.2)
# Requirement already satisfied: joblib<2.0.0,>=1.2.0 in c:\users\admin\anaconda3\lib\site-packages (from fuzzy-c-means) (1.3.1)
# Requirement already satisfied: tabulate<0.9.0,>=0.8.9 in c:\users\admin\anaconda3\lib\site-packages (from fuzzy-c-means) (0.8.10)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.1 in c:\users\admin\anaconda3\lib\site-packages (from fuzzy-c-means) (4.64.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<2.0.0,>=1.9.0->fuzzy-c-means) (4.4.0)
# Requirement already satisfied: colorama in c:\users\admin\appdata\roaming\python\python310\site-packages (from tqdm<5.0.0,>=4.64.1->fuzzy-c-means) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\admin\anaconda3\lib\site-packages (from typer<0.5.0,>=0.4.0->fuzzy-c-means) (8.0.4)

# %%
import numpy as np
from fcmeans import FCM
from matplotlib import pyplot as plt

# %% [markdown]
# ##Steps:
#
# - Fix the value of c (number of clusters), and select a value of m (generally 1.25<m<2), and initialize partition matrix U.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Calculate the cluster centroid

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Update Partition Matrix
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
n_samples = 5000
X = np.concatenate((
    np.random.normal((-2, -2), size=(n_samples, 2)),
    np.random.normal((2, 2), size=(n_samples, 2))
))

# %%
X
# Out:
# array([[-1.8780589 , -2.66224198],
#        [-2.40817078, -2.59913202],
#        [-0.98909425, -2.48697303],
#        ...,
#        [ 0.81428257,  1.9432958 ],
#        [-0.33402941,  2.12034173],
#        [ 1.42502298,  2.13924863]])

# %%
fcm = FCM(n_clusters=2)
fcm.fit(X)

# %%
fcm.centers
# Out:
# array([[-2.02203787, -1.99979289],
#        [ 2.03284212,  2.01675331]])

# %%
fcm.predict(X)
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int64)

# %%
fcm_clusters = fcm.centers
fcm_labels = fcm.predict(X)
f,axes = plt.subplots(1,2,figsize=(11,5))
axes[0].scatter(X[:,0],X[:,1],alpha=0.1)
axes[1].scatter(X[:,0],X[:,1],c = fcm_labels,alpha=.1)
axes[1].scatter(fcm_clusters[:,0],fcm_clusters[:,1],marker='+',s=500,c='w')
plt.show()
