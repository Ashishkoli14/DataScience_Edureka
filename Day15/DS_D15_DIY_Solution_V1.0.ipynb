# %% [markdown]
# ### Day 15 - DIY Solution

# %% [markdown]
# **Q1. Problem Statement: Data Grouping - I**
#
# Load the "big_bang_theory.csv" dataset provided on LMS into a DataFrame, group the data based on column "directed_by" using the groupby() function and the grouped DataFrame. Now also print all the episodes and the data associated with them, which belongs to the director - Mark Cendroski.

# %% [markdown]
# **Step-1:** Loading the dataset in a DataFrame.

# %%
# importing pandas package
import pandas as pd
import numpy as np
	
# making data frame from csv file
df = pd.read_csv("big_bang_theory_episodes.csv").fillna(np.nan)
df
# Out:
#      season  episode_num_in_season  episode_num_overall
# 0         1                      1                    1  \
# 1         1                      2                    2
# 2         1                      3                    3
# 3         1                      4                    4
# 4         1                      5                    5
# ..      ...                    ...                  ...
# 274      12                     20                  275
# 275      12                     21                  276
# 276      12                     22                  277
# 277      12                     23                  278
# 278      12                     24                  279
#
#                           title       directed_by
# 0                         Pilot     James Burrows  \
# 1       The Big Bran Hypothesis   Mark Cendrowski
# 2     The Fuzzy Boots Corollary   Mark Cendrowski
# 3      The Luminous Fish Effect   Mark Cendrowski
# ...

# %% [markdown]
# **Step-2:** Grouping the data based on director names.

# %%
#Grouping data based on director names
result = df.groupby('directed_by')
result

# %%
sample = pd.DataFrame(result)
sample
# Out:
#                    0                                                  1
# 0   Andrew D. Weyman     season  episode_num_in_season  episode_num_...
# 1       Anthony Rich       season  episode_num_in_season  episode_nu...
# 2        Gay Linvill       season  episode_num_in_season  episode_nu...
# 3      Howard Murray      season  episode_num_in_season  episode_num...
# 4      James Burrows     season  episode_num_in_season  episode_num_...
# 5        Joel Murray     season  episode_num_in_season  episode_num_...
# 6       Kristy Cecil       season  episode_num_in_season  episode_nu...
# 7    Mark Cendrowski       season  episode_num_in_season  episode_nu...
# 8        Nikki Lorre       season  episode_num_in_season  episode_nu...
# 9       Peter Chakos       season  episode_num_in_season  episode_nu...
# 10          Ted Wass     season  episode_num_in_season  episode_num_...

# %% [markdown]
# **Step-3:** Printing the rows related to director- Mark Cendrowski

# %%
#Printing individual groups
result.get_group('Mark Cendrowski')
# Out:
#      season  episode_num_in_season  episode_num_overall
# 1         1                      2                    2  \
# 2         1                      3                    3
# 3         1                      4                    4
# 5         1                      6                    6
# 6         1                      7                    7
# ..      ...                    ...                  ...
# 272      12                     18                  273
# 273      12                     19                  274
# 274      12                     20                  275
# 277      12                     23                  278
# 278      12                     24                  279
#
#                            title      directed_by
# 1        The Big Bran Hypothesis  Mark Cendrowski  \
# 2      The Fuzzy Boots Corollary  Mark Cendrowski
# 3       The Luminous Fish Effect  Mark Cendrowski
# 5      The Middle Earth Paradigm  Mark Cendrowski
# ...

# %% [markdown]
# **Q2. Problem Statement: Data Grouping - II**
#
# Load the "big_bang_theory.csv" dataset provided on LMS into a DataFrame; Group the data based on two columns, "directed_by" and "written_by," using the groupby() function and print the grouped DataFrame. Also, print the average viewers in the United States and the director and the writer's details.

# %% [markdown]
# **Step-1:** Loading the dataset in a DataFrame.

# %%
# importing pandas package
import pandas as pd
import numpy as np
	
# making data frame from csv file
df = pd.read_csv("big_bang_theory_episodes.csv")
display(df)
# Out:
#      season  episode_num_in_season  episode_num_overall
# 0         1                      1                    1  \
# 1         1                      2                    2
# 2         1                      3                    3
# 3         1                      4                    4
# 4         1                      5                    5
# ..      ...                    ...                  ...
# 274      12                     20                  275
# 275      12                     21                  276
# 276      12                     22                  277
# 277      12                     23                  278
# 278      12                     24                  279
#
#                           title       directed_by
# 0                         Pilot     James Burrows  \
# 1       The Big Bran Hypothesis   Mark Cendrowski
# 2     The Fuzzy Boots Corollary   Mark Cendrowski
# 3      The Luminous Fish Effect   Mark Cendrowski
# ...

# %% [markdown]
# **Step-2:** Average US viewers of each writer and director.

# %%
#Grouping data based on director and writer
result = df.groupby(['directed_by', 'written_by']) ['us_viewers'].mean()
result
# Out:
# directed_by       written_by
# Andrew D. Weyman  Story by: Jennifer GlickmanTeleplay by: Dave Goetsch & Steven Molaro                                                  8810000.0
# Anthony Rich      Chuck Lorre & Bill Prady & Lee Aronsohn & Steven Molaro                                                              11630000.0
#                   Story by: Bill Prady & Eric Kaplan & Jim ReynoldsTeleplay by: Steven Molaro & Dave Goetsch & Steve Holland           17730000.0
#                   Story by: Chuck Lorre & Bill Prady & Dave GoetschTeleplay by: Lee Aronsohn & Steven Molaro & Steve Holland           13630000.0
#                   Story by: Chuck Lorre & Bill Prady & Steve HollandTeleplay by: Steven Molaro & Eric Kaplan & Anthony Del Broccolo    14020000.0
#                                                                                                                                           ...
# ...

# %%
import pandas as pd 
# List1 
lst = [['apple', 'red', 11], ['grape', 'green', 22], ['orange', 'orange', 33], ['mango', 'yellow', 44]] 
df = pd.DataFrame(lst) 
print(df)
# Out:
#         0       1   2
# 0   apple     red  11
# 1   grape   green  22
# 2  orange  orange  33
# 3   mango  yellow  44
